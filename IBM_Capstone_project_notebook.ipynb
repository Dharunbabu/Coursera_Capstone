# %% [markdown]
#     Notebook for IBM Coursera Capstone project_Week1

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %% [markdown]
#     Start of IBM Coursera Capstone project_Week3_part_1

# %%
from sklearn.cluster import KMeans
import requests

url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

tables = pd.read_html(r.text)

# %%
df = pd.DataFrame(tables[0])
df_filtered = df[df['Borough'] != "Not assigned"]
df_filtered
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# ..          ...               ...
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# ...

# %%
df_filtered_2 = df_filtered.groupby("Postal Code").agg(lambda x:','.join(set(x)))

# %%
df_filtered_2.loc[df_filtered_2['Neighbourhood']=="Not assigned",'Neighbourhood']=df_filtered_2.loc[df_filtered_2['Neighbourhood']=="Not assigned",'Borough']
df_filtered_2
# Out:
#                  Borough                                      Neighbourhood
# Postal Code
# M1B          Scarborough                                     Malvern, Rouge
# M1C          Scarborough             Rouge Hill, Port Union, Highland Creek
# M1E          Scarborough                  Guildwood, Morningside, West Hill
# M1G          Scarborough                                             Woburn
# M1H          Scarborough                                          Cedarbrae
# ...                  ...                                                ...
# M9N                 York                                             Weston
# M9P            Etobicoke                                          Westmount
# M9R            Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# M9V            Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# M9W            Etobicoke                Northwest, West Humber - Clairville
#
# [103 rows x 2 columns]

# %%
df_filtered_2.shape
# Out:
# (103, 2)

# %% [markdown]
#     End of IBM Coursera Capstone project_Week3_part_1

# %% [markdown]
#     Start of IBM Coursera Capstone project_Week3_part_2_Geospatial_Data

# %%
df_geo = pd.read_csv("http://cocl.us/Geospatial_data")
df_geo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df_filtered_2['Latitude'] = df_geo['Latitude'].values
df_filtered_2['Longitude'] = df_geo['Longitude'].values
df_filtered_2
# Out:
#                  Borough                                      Neighbourhood  \
# Postal Code
# M1B          Scarborough                                     Malvern, Rouge
# M1C          Scarborough             Rouge Hill, Port Union, Highland Creek
# M1E          Scarborough                  Guildwood, Morningside, West Hill
# M1G          Scarborough                                             Woburn
# M1H          Scarborough                                          Cedarbrae
# ...                  ...                                                ...
# M9N                 York                                             Weston
# M9P            Etobicoke                                          Westmount
# M9R            Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# M9V            Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# M9W            Etobicoke                Northwest, West Humber - Clairville
#
#               Latitude  Longitude
# ...

# %% [markdown]
#     Start of IBM Coursera Capstone project_Week3_part_2_Geospatial_Data

# %%
#!conda install -c conda-forge folium=0.5.0 --yes
import folium

center_latitude=df_filtered_2.Latitude.mean()
center_longitude=df_filtered_2.Longitude.mean()

venues_map = folium.Map(location=[center_latitude, center_longitude], zoom_start=13) # generate map centred around the Conrad Hotel
for lat, lng in zip(df_filtered_2.Latitude, df_filtered_2.Longitude):
    folium.features.CircleMarker(
        [df_filtered_2[5]['Latitude'], df_filtered_2[5]['Longitude']],
        radius=2,
        color='red',
        popup=r['Neighbourhood'],
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.6
        ).add_to(venues_map)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Software\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-86b9f3624972> in <module>
# ...

# %%
for i, r in df_filtered_2.iterrows():
    folium.features.CircleMarker(
        [r['Latitude'], r['Longitude']],
        radius=2,
        color='red',
        popup=r['Neighbourhood'],
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
